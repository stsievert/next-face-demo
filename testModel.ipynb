# %%
import loader
import test_util as test
data, results = loader.load_face_data()

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso

# %%
test.train_and_print_metrics(results, data, Lasso(alpha=0.0009))
# Out:
# Average Distance: 	 0.5068232333729676
# Mean Distance: 		 0.4897464234137026

# %%
test.train_and_print_metrics(results, data, Lasso(alpha=0.001))
# Out:
# Average Distance: 	 0.5100782577554983
# Mean Distance: 		 0.48891197478940596

# %%
test.train_and_print_metrics(results, data, Lasso(alpha=0.01))
# Out:
# Average Distance: 	 0.6858159906693229
# Mean Distance: 		 0.6808479841987266

# %% [markdown]
# ## KernelRidge

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.kernel_ridge import KernelRidge

# %%
test.train_and_print_metrics(results, data, KernelRidge(alpha=0.001, kernel="polynomial", kernel_params={"d": 2}))
# Out:
# Average Distance: 	 0.47826566282120664
# Mean Distance: 		 0.4498470237829528

# %%
test.train_and_print_metrics(results, data, KernelRidge(alpha=0.01))
# Out:
# Average Distance: 	 0.5239746317742512
# Mean Distance: 		 0.5004897969622717

# %%
test.train_and_print_metrics(results, data, KernelRidge(alpha=0.1))
# Out:
# Average Distance: 	 0.46977950834644605
# Mean Distance: 		 0.44307640208095805

# %%
test.train_and_print_metrics(results, data, KernelRidge(alpha=1.0))
# Out:
# Average Distance: 	 0.49111892995285483
# Mean Distance: 		 0.464124989266788

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge

# %%
test.train_and_print_metrics(results, data, Ridge(alpha=0.001))
# Out:
# Average Distance: 	 0.6200517990171847
# Mean Distance: 		 0.5561304723905169

# %%
test.train_and_print_metrics(results, data, Ridge(alpha=0.01))
# Out:
# Average Distance: 	 0.5243145009017538
# Mean Distance: 		 0.5009917548043046

# %%
test.train_and_print_metrics(results, data, Ridge(alpha=0.1))
# Out:
# Average Distance: 	 0.4703207386432711
# Mean Distance: 		 0.44163368706110406

# %%
test.train_and_print_metrics(results, data, Ridge(alpha=1.0))
# Out:
# Average Distance: 	 0.49219193827605934
# Mean Distance: 		 0.46307344971870273

# %% [markdown]
# ## MultiTaskLasso

# %%
from sklearn.linear_model import MultiTaskLasso

# %%
test.train_and_print_metrics(results, data, MultiTaskLasso(alpha=0.001))
# Out:
# Average Distance: 	 0.49879134926600666
# Mean Distance: 		 0.4878323440197332

# %% [markdown]
# ## ElasticNet

# %%
from sklearn.linear_model import ElasticNet

# %%
test.train_and_print_metrics(results, data, ElasticNet(alpha=0.01))
# Out:
# Average Distance: 	 0.6184862144135319
# Mean Distance: 		 0.6049454765076816

# %%
test.train_and_print_metrics(results, data, ElasticNet(alpha=0.1))
# Out:
# Average Distance: 	 0.7745402855475906
# Mean Distance: 		 0.7564254494727436

# %%
test.train_and_print_metrics(results, data, ElasticNet(alpha=1.0))
# Out:
# Average Distance: 	 0.7745402855475906
# Mean Distance: 		 0.7564254494727436
